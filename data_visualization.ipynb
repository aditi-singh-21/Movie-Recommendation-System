# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("movie_list.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie Name    248 non-null    object
#  1   Rating        248 non-null    float64
#  2   Year          248 non-null    int64
#  3   Director      248 non-null    object
#  4   Writers       248 non-null    object
#  5   User Reviews  248 non-null    float64
#  6   Genre         248 non-null    object
#  7   Summary       248 non-null    object
#  8   URL           248 non-null    object
#  9   Cast 1        248 non-null    object
#  10  Cast 2        248 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 21.4+ KB

# %%
df['Year'].unique()
# Out:
# array([1993, 2023, 1987, 1979, 2003, 2022, 2018, 2021, 2009, 1959, 1989,
#        2020, 2019, 2004, 1991, 2007, 1957, 2016, 2015, 1992, 2013, 2001,
#        2005, 1983, 2006, 1956, 2014, 1998, 2012, 1955, 1975, 1988, 1995,
#        1965, 2017, 2011, 1997, 2024, 2002, 2000, 1999, 2010, 1982, 2008,
#        1971, 1964, 1996, 1960, 1994, 1968, 1958, 1970], dtype=int64)

# %%
df['Year'].value_counts()
# Out:
# Year
# 2019    16
# 2018    14
# 2016    14
# 2021    13
# 2012    12
# 2022    12
# 2015    12
# 2013    11
# 2023    11
# 2006     9
# 2017     9
# 2014     8
# 2003     8
# 2010     8
# 2004     7
# 2024     5
# 2011     5
# 1999     5
# 2020     4
# 2007     4
# 2009     4
# 1995     4
# 2005     4
# 2002     3
# 2000     3
# 1975     3
# 1993     3
# 2001     3
# 1992     3
# 1957     2
# 1997     2
# 1987     2
# 1996     2
# 1989     2
# 1991     2
# 2008     2
# 1988     2
# 1971     1
# 1994     1
# 1960     1
# 1968     1
# 1958     1
# 1964     1
# 1998     1
# 1959     1
# 1982     1
# 1979     1
# 1956     1
# 1965     1
# 1983     1
# 1955     1
# 1970     1
# Name: count, dtype: int64

# %%
plt.bar(df['Year'].unique() , df['Year'].value_counts() ,color= 'black')
plt.xlabel("Year")
plt.ylabel("Number of movies")
plt.title("Number of movies VS Year")
plt.show()

# %%
reviews = list(df['User Reviews'])
name = list(df['Movie Name'])

df_name_reviews = pd.DataFrame({'User Reviews' : reviews , 'Movie Name' : name})
df_name_reviews = df_name_reviews.sort_values(by='User Reviews',ascending=False)
plt.barh(df_name_reviews['Movie Name'].iloc[0:10], df_name_reviews['User Reviews'].iloc[0:10],color= 'black')
plt.xlabel("User Ratings")
plt.ylabel("Movie Name")
plt.title("Movie vs User Rating")
plt.show()

# %%
reviews = list(df['User Reviews'])
name = list(df['Movie Name'])

df_name_reviews = pd.DataFrame({'User Reviews' : reviews , 'Movie Name' : name})
df_name_reviews = df_name_reviews.sort_values(by='User Reviews')
#plt.barh(df_name_reviews['Movie Name'].iloc[0:10], df_name_reviews['User Reviews'].iloc[0:10],color= 'black')
plt.barh(df_name_reviews['Movie Name'].iloc[0:10], df_name_reviews['User Reviews'].iloc[0:10],color= 'black')
plt.xlabel("User Ratings")
plt.ylabel("Movie Name")
plt.title("Movie vs User Rating")
plt.show()

# %%
rating = list(df['Rating'])
name = list(df['Movie Name'])

df_name_rating = pd.DataFrame({'Rating' : rating , 'Movie Name' : name})
df_name_rating = df_name_rating.sort_values(by='Rating',ascending=False)
plt.bar(df_name_rating['Movie Name'].iloc[0:10], df_name_rating['Rating'].iloc[0:10],color= 'black')
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2,y[i], ha = 'center',bbox = dict(facecolor = 'white', alpha = .5))
rating = list(df_name_rating['Rating'])[0:10]
name = list(df_name_rating['Movie Name'])[0:10]
addlabels(name,rating)
plt.xlabel("Rating")
plt.xticks(rotation=90)
plt.ylabel("Movie")
plt.title(" Top 250 movies")
plt.show()

# %%
rating = list(df['Rating'])
name = list(df['Movie Name'])

df_name_rating = pd.DataFrame({'Rating' : rating , 'Movie Name' : name})
df_name_rating = df_name_rating.sort_values(by='Rating')
plt.bar(df_name_rating['Movie Name'].iloc[0:10], df_name_rating['Rating'].iloc[0:10],color= 'black')
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2,y[i], ha = 'center',bbox = dict(facecolor = 'white', alpha = .5))
rating = list(df_name_rating['Rating'])[0:10]
name = list(df_name_rating['Movie Name'])[0:10]
addlabels(name,rating)
plt.xlabel("Rating")
plt.xticks(rotation=90)
plt.ylabel("Movie")
plt.title("Lower Top 250 movies")
plt.show()

# %%
genre_count = list(df['Genre'].value_counts())[0:7]
genre_name = ['Action' ,'Comedy' ,'Drama' ,'Crime' ,'Biography' ,'Adventure','Mystery']
plt.pie(genre_count,labels=genre_name,autopct='%1.2f%%',textprops={'fontsize':6},colors=sns.color_palette(palette='binary'))
plt.show()

# %%
cast1_value = list(df['Cast 1'].value_counts())[:10]
cast1_name = ['Kamal Hassan','Mohanlal','Aamir Khan','Ajay Devgan','Akshay Kumar','Shah Rukh Khan','Dhanush','Irrfan Khan','Vijay Sethupathi','Joseph Vijay']
plt.bar(cast1_name, cast1_value,color= 'black')
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2,y[i], ha = 'center',bbox = dict(facecolor = 'white', alpha = .5))
addlabels(cast1_name,cast1_value)
plt.xlabel("Cast 1")
plt.xticks(rotation=90)
plt.ylabel("Count")
plt.title("Count of Cast 1")
plt.show()

# %%
cast2_value = list(df['Cast 2'].value_counts())[:10]
cast2_name = ['Suraj Venjaramoodu','Simran','Mrunal Thakur','Vijay Sethupathi','Tabu','Trisha Krishnan','Thilakan','Naseeruddin Shah','Rana Daggubati','Anushka Shetty']
plt.bar(cast2_name, cast2_value,color= 'black')
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2,y[i], ha = 'center',bbox = dict(facecolor = 'white', alpha = .5))
addlabels(cast2_name,cast2_value)
plt.xlabel("Cast 2")
plt.xticks(rotation=90)
plt.ylabel("Count")
plt.title("Count of Cast 2")
plt.show()

# %%
dir_value = list(df['Director'].value_counts())[:10]
dir_name = ['Mani Ratnam','Anurag Kashyap','Vetrimaaran','Satyajit Ray','Rajkumar Hirani','Gautham Vasudev Menon','Jeethu Joseph','Hrishikesh Mukherjee','Karthik Subbaraj','S. Shankar']
plt.bar(dir_name, dir_value,color= 'black')
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i]//2,y[i], ha = 'center',bbox = dict(facecolor = 'white', alpha = .5))
addlabels(dir_name,dir_value)
plt.xlabel("Director")
plt.xticks(rotation=90)
plt.ylabel("Count")
plt.title("Count of Director")
plt.show()

# %%
df['Movie Name'].value_counts()
# Out:
# Movie Name
# Ramayana: The Legend of Prince Rama    1
# Garuda Gamana Vrishabha Vahana         1
# Aadukalam                              1
# Naduvula Konjam Pakkatha Kaanom        1
# Padosan                                1
#                                       ..
# Lagaan: Once Upon a Time in India      1
# PK                                     1
# Jigarthanda                            1
# Soodhu Kavvum                          1
# Poove Unakkaga                         1
# Name: count, Length: 248, dtype: int64
